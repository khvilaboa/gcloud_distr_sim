# %%
import os
import pandas as pd
import re

# %% [markdown]
# ### Atomic proportion

# %%
data_folder = "../data/fixed-75-perc-fast"

# %%
filter_contains = "ChiSquared"
data = []

def num_fast_slow(fn):
    with open(fn, "r") as in_xml:
        xml_str = in_xml.read()
        return xml_str.count("fast"), xml_str.count("slow")

for file in os.listdir(data_folder):
    if not filter_contains in file or not file.endswith(".xml"):
        continue
        
    match = re.search("s-([0-9]+).*_p([0-9]+)-([0-9]+)", file)
    if not match:
        continue
    
    num_fast, num_slow = num_fast_slow(os.path.join(data_folder, file))
    num_fast -= 2
    data.append(match.groups() + (num_fast, num_slow))

# %%
data = sorted(data, key=lambda x: int(x[1]))
df = pd.DataFrame(data, columns=["size", "pods_fast", "pods_slow", "atomics_fast", "atomics_slow"])

# %%
df
# Out:
#    size pods_fast pods_slow  atomics_fast  atomics_slow
# 0    15         1         1           147            50
# 1    15         1         7           147            50
# 2    15         2         1           147            50
# 3    15         2         6           147            50
# 4    15         3         1           147            50
# 5    15         3         5           147            50
# 6    15         4         1           147            50
# 7    15         4         4           147            50
# 8    15         5         1           147            50
# 9    15         5         3           147            50
# 10   15         6         1           147            50
# 11   15         6         2           147            50
# 12   15         7         1           147            50
# 13   15         7        10           147            50
# 14   15         7        15           147            50
# 15   15         7         2           147            50
# ...
